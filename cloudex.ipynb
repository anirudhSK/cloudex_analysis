# %%
import pandas

# %%
# %time cloudex_df = pandas.read_csv("/Users/anirudh/Downloads/up_df_competition_11_05.csv")
# Out:
# CPU times: user 1min 22s, sys: 34.4 s, total: 1min 56s
# Wall time: 2min 9s

# %%
cloudex_df
# Out:
#             Client-Qual-Recv                             Order-ID  \
# 0        client_log_recv_c36  AA.00023016045445818229201200000036
# 1        client_log_recv_c34  AK.00011616045445818231741200000034
# 2        client_log_recv_c36  AE.00017816045445818250731200000136
# 3        client_log_recv_c34  AG.00032616045445818251771200000134
# 4        client_log_recv_c36  AY.00037716045445818265001200000236
# ...                      ...                                  ...
# 8389284  client_log_recv_c34  CW.00000016045523999552011211057534
# 8389285  client_log_recv_c34  CW.00000016045523999564001211057634
# 8389286  client_log_recv_c34  CW.00000016045523999574881211057734
# 8389287  client_log_recv_c34  CW.00000016045523999586891211057834
# 8389288  client_log_recv_c34  CW.00000016045523999600471211057934
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 0                 8145454              1604544581825426  gateway_log_up
# ...

# %%
cloudex_df.groupby(['Gateway-Num']).mean()
# Out:
#              Order-Serial-Num  Confirmation-Submission-Time  \
# Gateway-Num
# g1               2.979950e+03                  1.604549e+15
# g11              9.162418e+06                  1.604548e+15
# g12              9.164899e+06                  1.604548e+15
# g2               1.549658e+03                  1.604548e+15
# g3               4.644000e+03                  1.604550e+15
# g4               3.358461e+06                  1.604548e+15
# g5               5.253823e+03                  1.604548e+15
# g6               6.528228e+02                  1.604548e+15
# g7               1.355500e+03                  1.604548e+15
# g8               2.355000e+02                  1.604546e+15
#
#              In-Sequence-Buffer-Confirmation-Timestamp  \
# Gateway-Num
# g1                                        1.604549e+15
# g11                                       1.604548e+15
# g12                                       1.604548e+15
# ...

# %%
cloudex_df.query('`Gateway-Num` == "g4"'')
# Out:
#   File "<ipython-input-7-33bd27a27e1c>", line 1
#     cloudex_df.query('`Gateway-Num` == "g4"'')
#                                               ^
# SyntaxError: EOL while scanning string literal

# %%
cloudex_df.query('`Gateway-Num` == "g4")
# Out:
#   File "<ipython-input-8-ea0cb5165187>", line 1
#     cloudex_df.query('`Gateway-Num` == "g4")
#                                             ^
# SyntaxError: EOL while scanning string literal

# %%
cloudex_df.query('`Gateway-Num` == "g4"')
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 1045787  client_log_recv_c11  AE.0998351604545552448551400000011
# 1045790  client_log_recv_c11  AE.0998361604545552450118400000111
# 1045792  client_log_recv_c11  AE.0998371604545552451572400000211
# 1045794  client_log_recv_c11  AE.0998381604545552452955400000311
# 1045797  client_log_recv_c11  AE.0002201604545552454283400000411
# ...                      ...                                 ...
# 8293273  client_log_recv_c11  BD.0996201604552260864019435106411
# 8296759  client_log_recv_c11  CZ.0996111604552263931293435106511
# 8297523  client_log_recv_c11  BC.0995921604552264604127435106611
# 8297732  client_log_recv_c11  BD.0996211604552264793779435106711
# 8298013  client_log_recv_c11  DA.0996071604552264957395435106811
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 1045787           3340133              1604545552450101  gateway_log_up
# ...

# %%
g4_orders=cloudex_df.query('`Gateway-Num` == "g4"')

# %%
g4_orders.groupby('Client-Num').mean()
# Out:
#             Order-Serial-Num  Confirmation-Submission-Time  \
# Client-Num
# c11             3.358461e+06                  1.604548e+15
#
#             In-Sequence-Buffer-Confirmation-Timestamp  \
# Client-Num
# c11                                      1.604548e+15
#
#             Order-Processed-Confirmation-Timestamp  \
# Client-Num
# c11                                   1.604548e+15
#
#             Real-Order-Gateway-Timestamp  Genesis-Timestamp  \
# Client-Num
# c11                         1.604548e+15       1.604548e+15
#
#             Gateway-Timestamp  Enqueue-Timestamp  Dequeue-Timestamp  \
# Client-Num
# c11              1.604548e+15       1.604548e+15       1.604548e+15
#
#             Buffer-Length-Deque  ...    Serial-Num  Num-Shares         1  \
# Client-Num                       ...
# c11                    0.094854  ...  3.358461e+06         NaN  0.220886
#
#                    2        3         4         5           6  \
# Client-Num
# ...

# %%
g4_orders
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 1045787  client_log_recv_c11  AE.0998351604545552448551400000011
# 1045790  client_log_recv_c11  AE.0998361604545552450118400000111
# 1045792  client_log_recv_c11  AE.0998371604545552451572400000211
# 1045794  client_log_recv_c11  AE.0998381604545552452955400000311
# 1045797  client_log_recv_c11  AE.0002201604545552454283400000411
# ...                      ...                                 ...
# 8293273  client_log_recv_c11  BD.0996201604552260864019435106411
# 8296759  client_log_recv_c11  CZ.0996111604552263931293435106511
# 8297523  client_log_recv_c11  BC.0995921604552264604127435106611
# 8297732  client_log_recv_c11  BD.0996211604552264793779435106711
# 8298013  client_log_recv_c11  DA.0996071604552264957395435106811
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 1045787           3340133              1604545552450101  gateway_log_up
# ...

# %%
g4_orders.groupby('Client-Num')

# %%
g4_orders.groupby('Client-Num').mean()
# Out:
#             Order-Serial-Num  Confirmation-Submission-Time  \
# Client-Num
# c11             3.358461e+06                  1.604548e+15
#
#             In-Sequence-Buffer-Confirmation-Timestamp  \
# Client-Num
# c11                                      1.604548e+15
#
#             Order-Processed-Confirmation-Timestamp  \
# Client-Num
# c11                                   1.604548e+15
#
#             Real-Order-Gateway-Timestamp  Genesis-Timestamp  \
# Client-Num
# c11                         1.604548e+15       1.604548e+15
#
#             Gateway-Timestamp  Enqueue-Timestamp  Dequeue-Timestamp  \
# Client-Num
# c11              1.604548e+15       1.604548e+15       1.604548e+15
#
#             Buffer-Length-Deque  ...    Serial-Num  Num-Shares         1  \
# Client-Num                       ...
# c11                    0.094854  ...  3.358461e+06         NaN  0.220886
#
#                    2        3         4         5           6  \
# Client-Num
# ...

# %%
g4_orders
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 1045787  client_log_recv_c11  AE.0998351604545552448551400000011
# 1045790  client_log_recv_c11  AE.0998361604545552450118400000111
# 1045792  client_log_recv_c11  AE.0998371604545552451572400000211
# 1045794  client_log_recv_c11  AE.0998381604545552452955400000311
# 1045797  client_log_recv_c11  AE.0002201604545552454283400000411
# ...                      ...                                 ...
# 8293273  client_log_recv_c11  BD.0996201604552260864019435106411
# 8296759  client_log_recv_c11  CZ.0996111604552263931293435106511
# 8297523  client_log_recv_c11  BC.0995921604552264604127435106611
# 8297732  client_log_recv_c11  BD.0996211604552264793779435106711
# 8298013  client_log_recv_c11  DA.0996071604552264957395435106811
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 1045787           3340133              1604545552450101  gateway_log_up
# ...

# %%
g4_orders["Confirmation-Latency-ms"].plot()

# %%
g12_orders=cloudex_df.query('`Gateway-Num` == "g12"')

# %%
g12_orders["Confirmation-Latency-ms"].plot()

# %%
cloudex_df["Gateway-Num"].unique()
# Out:
# array(['g12', 'g11', 'g2', 'g1', 'g8', 'g4', 'g5', 'g7', 'g3', 'g6'],
#       dtype=object)

# %%
cloudex_df["Client-Num"].unique()
# Out:
# array(['c36', 'c34', 'c35', 'c33', 'c31', 'c6', 'c3', 'c22', 'c11', 'c15',
#        'c21', 'c9', 'c1', 'c17', 'c2', 'c18', 'c14', 'c5'], dtype=object)

# %%
len(cloudex_df["Client-Num"].unique())
# Out:
# 18

# %%
len(cloudex_df["Gateway-Num"].unique())
# Out:
# 10

# %%
g4_orders.count()
# Out:
# Client-Qual-Recv                             347227
# Order-ID                                     347227
# Order-Serial-Num                             347227
# Confirmation-Submission-Time                 347227
# GW-Qual                                      347227
# Gateway-Num                                  347227
# Client-Num                                   347227
# In-Sequence-Buffer-Confirmation-Timestamp    347227
# Order-Processed-Confirmation-Timestamp       347227
# Real-Order-Gateway-Timestamp                 347227
# ME-Qual                                      347227
# Serialized-Order-String                      347227
# Order-ID-ME                                  347227
# Genesis-Timestamp                            347227
# Gateway-Timestamp                            347227
# Enqueue-Timestamp                            347227
# Dequeue-Timestamp                            347227
# Buffer-Length-Deque                          347227
# ...

# %%
g12_orders.count()
# Out:
# Client-Qual-Recv                             6031370
# Order-ID                                     6031370
# Order-Serial-Num                             6031370
# Confirmation-Submission-Time                 6031370
# GW-Qual                                      6031370
# Gateway-Num                                  6031370
# Client-Num                                   6031370
# In-Sequence-Buffer-Confirmation-Timestamp    6031370
# Order-Processed-Confirmation-Timestamp       6031370
# Real-Order-Gateway-Timestamp                 6031370
# ME-Qual                                      6031370
# Serialized-Order-String                      6031370
# Order-ID-ME                                  6031370
# Genesis-Timestamp                            6031370
# Gateway-Timestamp                            6031370
# Enqueue-Timestamp                            6031370
# Dequeue-Timestamp                            6031370
# Buffer-Length-Deque                          6031370
# ...

# %%
g4_orders
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 1045787  client_log_recv_c11  AE.0998351604545552448551400000011
# 1045790  client_log_recv_c11  AE.0998361604545552450118400000111
# 1045792  client_log_recv_c11  AE.0998371604545552451572400000211
# 1045794  client_log_recv_c11  AE.0998381604545552452955400000311
# 1045797  client_log_recv_c11  AE.0002201604545552454283400000411
# ...                      ...                                 ...
# 8293273  client_log_recv_c11  BD.0996201604552260864019435106411
# 8296759  client_log_recv_c11  CZ.0996111604552263931293435106511
# 8297523  client_log_recv_c11  BC.0995921604552264604127435106611
# 8297732  client_log_recv_c11  BD.0996211604552264793779435106711
# 8298013  client_log_recv_c11  DA.0996071604552264957395435106811
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 1045787           3340133              1604545552450101  gateway_log_up
# ...

# %%
cloudex_df
# Out:
#             Client-Qual-Recv                             Order-ID  \
# 0        client_log_recv_c36  AA.00023016045445818229201200000036
# 1        client_log_recv_c34  AK.00011616045445818231741200000034
# 2        client_log_recv_c36  AE.00017816045445818250731200000136
# 3        client_log_recv_c34  AG.00032616045445818251771200000134
# 4        client_log_recv_c36  AY.00037716045445818265001200000236
# ...                      ...                                  ...
# 8389284  client_log_recv_c34  CW.00000016045523999552011211057534
# 8389285  client_log_recv_c34  CW.00000016045523999564001211057634
# 8389286  client_log_recv_c34  CW.00000016045523999574881211057734
# 8389287  client_log_recv_c34  CW.00000016045523999586891211057834
# 8389288  client_log_recv_c34  CW.00000016045523999600471211057934
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 0                 8145454              1604544581825426  gateway_log_up
# ...

# %%
cloudex_df["Gateway-Num"].unique()
# Out:
# array(['g12', 'g11', 'g2', 'g1', 'g8', 'g4', 'g5', 'g7', 'g3', 'g6'],
#       dtype=object)

# %%
cloudex_df.query('`Gateway-Num` == "g4"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g3"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g4"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g5"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g6"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g7"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g8"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g9"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g10"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g11"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g12"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.groupby(['Gateway-Num']).count()
# Out:
#              Client-Qual-Recv  Order-ID  Order-Serial-Num  \
# Gateway-Num
# g1                       2891      2891              2891
# g11                   2005020   2005020           2005020
# g12                   6031370   6031370           6031370
# g2                        193       193               193
# g3                       1451      1451              1451
# g4                     347227    347227            347227
# g5                        181       181               181
# g6                        756       756               756
# g7                        164       164               164
# g8                         36        36                36
#
#              Confirmation-Submission-Time  GW-Qual  Client-Num  \
# Gateway-Num
# g1                                   2891     2891        2891
# g11                               2005020  2005020     2005020
# g12                               6031370  6031370     6031370
# ...

# %%
g4_orders
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 1045787  client_log_recv_c11  AE.0998351604545552448551400000011
# 1045790  client_log_recv_c11  AE.0998361604545552450118400000111
# 1045792  client_log_recv_c11  AE.0998371604545552451572400000211
# 1045794  client_log_recv_c11  AE.0998381604545552452955400000311
# 1045797  client_log_recv_c11  AE.0002201604545552454283400000411
# ...                      ...                                 ...
# 8293273  client_log_recv_c11  BD.0996201604552260864019435106411
# 8296759  client_log_recv_c11  CZ.0996111604552263931293435106511
# 8297523  client_log_recv_c11  BC.0995921604552264604127435106611
# 8297732  client_log_recv_c11  BD.0996211604552264793779435106711
# 8298013  client_log_recv_c11  DA.0996071604552264957395435106811
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 1045787           3340133              1604545552450101  gateway_log_up
# ...

# %%
g4_orders.loc()

# %%
g4_orders.plot(x='Order-Processed-Confirmation-Timestamp', y='Confirmation-Latency-ms')

# %%
g4_orders.plot(y='Confirmation-Latency-ms')

# %%
g4_orders.query('`Confirmation-Latency-ms` > 50000')
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 5733546  client_log_recv_c11  DA.0003831604549818382269425759511
# 5733986  client_log_recv_c11  BC.0003991604549818719809425759611
# 5734427  client_log_recv_c11  BD.0996331604549819078753425759711
# 5735423  client_log_recv_c11  CY.0995021604549819940540425759811
# 5735958  client_log_recv_c11  DA.0003831604549820406521425759911
# ...                      ...                                 ...
# 6740912  client_log_recv_c11  CZ.0003781604550892965152427646711
# 6741216  client_log_recv_c11  CY.0005211604550893246229427646811
# 6741727  client_log_recv_c11  BD.0003721604550893681898427646911
# 6743878  client_log_recv_c11  CO.0996171604550895567885427647011
# 6743938  client_log_recv_c11  DA.0003951604550895620247427647111
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 5733546                28              1604550030218645  gateway_log_up
# ...

# %%
pandas.options.display.max_rows
# Out:
# 60

# %%
pandas.options.display.max_rows = None

# %%
pandas.options.display.max_rows

# %%
x = 5

# %%
pandas.options.display.max_rows = 60

# %%
cloudex_df
# Out:
#             Client-Qual-Recv                             Order-ID  \
# 0        client_log_recv_c36  AA.00023016045445818229201200000036
# 1        client_log_recv_c34  AK.00011616045445818231741200000034
# 2        client_log_recv_c36  AE.00017816045445818250731200000136
# 3        client_log_recv_c34  AG.00032616045445818251771200000134
# 4        client_log_recv_c36  AY.00037716045445818265001200000236
# ...                      ...                                  ...
# 8389284  client_log_recv_c34  CW.00000016045523999552011211057534
# 8389285  client_log_recv_c34  CW.00000016045523999564001211057634
# 8389286  client_log_recv_c34  CW.00000016045523999574881211057734
# 8389287  client_log_recv_c34  CW.00000016045523999586891211057834
# 8389288  client_log_recv_c34  CW.00000016045523999600471211057934
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 0                 8145454              1604544581825426  gateway_log_up
# ...

# %%
len(cloudex_df["Order-Serial-Num"].unique())
# Out:
# 2475572

# %%
len(cloudex_df)
# Out:
# 8389289

# %%
cloudex_df.groupby("Order-Serial-Num")

# %%
cloudex_df.groupby("Order-Serial-Num").count()
# Out:
#                   Client-Qual-Recv  Order-ID  Confirmation-Submission-Time  \
# Order-Serial-Num
# 1                                5         5                             5
# 2                                4         4                             4
# 3                                5         5                             5
# 4                                4         4                             4
# 5                                4         4                             4
# ...                            ...       ...                           ...
# 10257590                         1         1                             1
# 10257591                         1         1                             1
# 10257592                         1         1                             1
# 10257593                         1         1                             1
# 10257605                         1         1                             1
#
# ...

# %%
unique_orders=cloudex_df.groupby("Order-Serial-Num").count()["1"]

# %%
type(unique_orders)
# Out:
# pandas.core.series.Series

# %%
unique_orders.sort_values(ascending=False)
# Out:
# Order-Serial-Num
# 1           5
# 3           5
# 14          5
# 8826385     4
# 8826390     4
#            ..
# 3592116     1
# 3592117     1
# 3592118     1
# 3592119     1
# 10257605    1
# Name: 1, Length: 2475572, dtype: int64

# %%
cloudex_df.query('`Order-Serial-Num` == 1')
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 4687944  client_log_recv_c18  AM.0001411604548786567184600000018
# 7245438  client_log_recv_c11  CZ.0003811604551345755644429528711
# 7670995   client_log_recv_c5   BP.099567160455171221457720000005
# 7745002  client_log_recv_c11  AP.0000001604551776959979432866811
# 8298013  client_log_recv_c11  DA.0996071604552264957395435106811
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 4687944                 1              1604548786569643  gateway_log_up
# 7245438                 1              1604551345757461  gateway_log_up
# 7670995                 1              1604551712216894  gateway_log_up
# 7745002                 1              1604551776961453  gateway_log_up
# 8298013                 1              1604552264958849  gateway_log_up
#
#         Gateway-Num Client-Num  In-Sequence-Buffer-Confirmation-Timestamp  \
# ...

# %%
cloudex_df.query('`Order-Serial-Num` == 3')
# Out:
#             Client-Qual-Recv                             Order-ID  \
# 470570   client_log_recv_c31  AA.09999916045450157195191100000031
# 5028073  client_log_recv_c18   AP.0000941604549099306388600000218
# 7245446  client_log_recv_c11   BU.0000001604551345758960429528911
# 7672095   client_log_recv_c5    BP.099567160455171323267720000025
# 7745011  client_log_recv_c11   AP.0000001604551776962710432867011
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 470570                  3              1604545015722009  gateway_log_up
# 5028073                 3              1604549099308077  gateway_log_up
# 7245446                 3              1604551345760153  gateway_log_up
# 7672095                 3              1604551713234186  gateway_log_up
# 7745011                 3              1604551776967282  gateway_log_up
#
#         Gateway-Num Client-Num  In-Sequence-Buffer-Confirmation-Timestamp  \
# ...

# %%
cloudex_df.query('`Order-Serial-Num` == 14')
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 5881139  client_log_recv_c14  AA.0998001604550024732630500000014
# 6547105  client_log_recv_c11  CY.0994891604550714546297427620611
# 7245479  client_log_recv_c11  AP.0998681604551345780045429530011
# 7745116  client_log_recv_c11  AM.0998331604551776996224432868111
# 7917618   client_log_recv_c5   BP.099560160455192384431720000135
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 5881139                14              1604550024734157  gateway_log_up
# 6547105                14              1604550945557822  gateway_log_up
# 7245479                14              1604551345781236  gateway_log_up
# 7745116                14              1604551776997235  gateway_log_up
# 7917618                14              1604551923845827  gateway_log_up
#
#         Gateway-Num Client-Num  In-Sequence-Buffer-Confirmation-Timestamp  \
# ...

# %%
cloudex_df.query('`Order-Serial-Num` == 8826385')
# Out:
#             Client-Qual-Recv                             Order-ID  \
# 2849893  client_log_recv_c36  AE.00016316045471053209711268093136
# 2912142  client_log_recv_c35  BL.00000016045471618426271269281035
# 2921773  client_log_recv_c33  AX.00000016045471707858511169791033
# 2993031  client_log_recv_c34  AO.00043916045472374192131271633434
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 2849893           8826385              1604547105322363  gateway_log_up
# 2912142           8826385              1604547161843725  gateway_log_up
# 2921773           8826385              1604547170787061  gateway_log_up
# 2993031           8826385              1604547237420410  gateway_log_up
#
#         Gateway-Num Client-Num  In-Sequence-Buffer-Confirmation-Timestamp  \
# 2849893         g12        c36                           1604547105321327
# 2912142         g12        c35                           1604547161842895
# ...

# %%
cloudex_df.query('`Order-Serial-Num` == 8826390')
# Out:
#             Client-Qual-Recv                             Order-ID  \
# 2849904  client_log_recv_c36  AE.00016116045471053270271268093636
# 2912151  client_log_recv_c35  BD.00000016045471618483741269281535
# 2921787  client_log_recv_c33  AX.00000016045471707912841169791533
# 2993051  client_log_recv_c34  AO.09956316045472374254361271633934
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 2849904           8826390              1604547105328309  gateway_log_up
# 2912151           8826390              1604547161849504  gateway_log_up
# 2921787           8826390              1604547170792320  gateway_log_up
# 2993051           8826390              1604547237426708  gateway_log_up
#
#         Gateway-Num Client-Num  In-Sequence-Buffer-Confirmation-Timestamp  \
# 2849904         g12        c36                           1604547105327502
# 2912151         g12        c35                           1604547161848717
# ...

# %%
cloudex_df.groupby(["Order-Serial-Num", "Client-Num"]).count()
# Out:
#                              Client-Qual-Recv  Order-ID  \
# Order-Serial-Num Client-Num
# 1                c11                        3         3
#                  c18                        1         1
#                  c5                         1         1
# 2                c11                        2         2
#                  c18                        1         1
# ...                                       ...       ...
# 10257590         c36                        1         1
# 10257591         c36                        1         1
# 10257592         c36                        1         1
# 10257593         c36                        1         1
# 10257605         c36                        1         1
#
#                              Confirmation-Submission-Time  GW-Qual  \
# Order-Serial-Num Client-Num
# 1                c11                                    3        3
#                  c18                                    1        1
# ...

# %%
cloudex_df
# Out:
#             Client-Qual-Recv                             Order-ID  \
# 0        client_log_recv_c36  AA.00023016045445818229201200000036
# 1        client_log_recv_c34  AK.00011616045445818231741200000034
# 2        client_log_recv_c36  AE.00017816045445818250731200000136
# 3        client_log_recv_c34  AG.00032616045445818251771200000134
# 4        client_log_recv_c36  AY.00037716045445818265001200000236
# ...                      ...                                  ...
# 8389284  client_log_recv_c34  CW.00000016045523999552011211057534
# 8389285  client_log_recv_c34  CW.00000016045523999564001211057634
# 8389286  client_log_recv_c34  CW.00000016045523999574881211057734
# 8389287  client_log_recv_c34  CW.00000016045523999586891211057834
# 8389288  client_log_recv_c34  CW.00000016045523999600471211057934
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 0                 8145454              1604544581825426  gateway_log_up
# ...

# %%
strange_orders=[x[0] for x in
                    list(cloudex_df.groupby(["Order-Serial-Num", "Client-Num"])
                    .count()['1']
                    .sort_values(ascending=False)
                    .to_frame()
                    .query('`1` != 1')
                    .index)
               ]

# %%
cloudex_df.query('`Client-Num` == "c11"')
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 1045787  client_log_recv_c11  AE.0998351604545552448551400000011
# 1045790  client_log_recv_c11  AE.0998361604545552450118400000111
# 1045792  client_log_recv_c11  AE.0998371604545552451572400000211
# 1045794  client_log_recv_c11  AE.0998381604545552452955400000311
# 1045797  client_log_recv_c11  AE.0002201604545552454283400000411
# ...                      ...                                 ...
# 8293273  client_log_recv_c11  BD.0996201604552260864019435106411
# 8296759  client_log_recv_c11  CZ.0996111604552263931293435106511
# 8297523  client_log_recv_c11  BC.0995921604552264604127435106611
# 8297732  client_log_recv_c11  BD.0996211604552264793779435106711
# 8298013  client_log_recv_c11  DA.0996071604552264957395435106811
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 1045787           3340133              1604545552450101  gateway_log_up
# ...

# %%
strange_orders
# Out:
# [1,
#  4325,
#  4314,
#  4315,
#  4316,
#  4317,
#  4318,
#  4319,
#  4320,
#  4321,
#  4322,
#  4323,
#  4324,
#  4326,
#  4339,
#  4327,
#  4328,
#  4329,
#  4330,
#  4331,
#  4332,
#  4333,
#  4334,
#  4335,
#  4336,
#  4337,
#  4313,
#  4312,
#  4311,
#  4310,
#  4287,
#  4288,
#  4289,
#  4290,
#  4291,
#  4292,
#  4293,
#  4294,
#  4295,
#  4296,
#  4297,
#  4298,
#  4299,
#  4300,
#  4301,
#  4302,
#  4303,
#  4304,
#  4305,
#  4306,
#  4307,
#  4308,
#  4309,
#  4338,
#  4340,
#  4612,
#  4380,
#  4369,
#  4370,
#  4371,
#  4372,
#  4373,
#  4374,
#  4375,
#  4376,
#  4377,
#  4378,
#  4379,
#  4381,
#  4341,
#  4382,
#  4383,
#  4384,
#  4385,
#  4386,
#  4387,
#  4388,
#  4389,
#  4390,
#  4391,
#  4392,
#  4368,
#  4367,
#  4366,
#  4365,
#  4342,
#  4343,
#  4344,
#  4345,
#  4346,
#  4347,
#  4348,
#  4349,
#  4350,
#  4351,
#  4352,
#  4353,
#  4354,
#  4355,
#  4356,
#  4357,
#  4358,
#  4359,
#  4360,
#  4361,
#  4362,
#  4363,
#  4364,
#  4286,
#  4285,
#  4284,
# ...

# %%
cloudex_df['Gateway-Num'].unique()
# Out:
# array(['g12', 'g11', 'g2', 'g1', 'g8', 'g4', 'g5', 'g7', 'g3', 'g6'],
#       dtype=object)

# %%
cloudex_df['Client-Num'].unique()
# Out:
# array(['c36', 'c34', 'c35', 'c33', 'c31', 'c6', 'c3', 'c22', 'c11', 'c15',
#        'c21', 'c9', 'c1', 'c17', 'c2', 'c18', 'c14', 'c5'], dtype=object)

# %%
cloudex_df.loc(cloudex_df['Order-Serial-Num'] not in strange_orders)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-f4feb00e86e4> in <module>
# ----> 1 cloudex_df.loc(cloudex_df['Order-Serial-Num'] not in strange_orders)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
cloudex_df.loc(cloudex_df['Order-Serial-Num'].isin(strange_orders))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-53722e487007> in <module>
# ----> 1 cloudex_df.loc(cloudex_df['Order-Serial-Num'].isin(strange_orders))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     576
#     577         if axis is not None:
# --> 578             axis = self.obj._get_axis_number(axis)
#     579         new_self.axis = axis
#     580         return new_self
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     396     @classmethod
#     397     def _get_axis_number(cls, axis):
# --> 398         axis = cls._AXIS_ALIASES.get(axis, axis)
#     399         if is_integer(axis):
#     400             if axis in cls._AXIS_NAMES:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __hash__(self)
#    1796
# ...

# %%
cloudex_df[cloudex_df['Order-Serial-Num'].isin(strange_orders)]
# Out:
#             Client-Qual-Recv                             Order-ID  \
# 470570   client_log_recv_c31  AA.09999916045450157195191100000031
# 829562    client_log_recv_c6    AC.000054160454535131558320000006
# 840372    client_log_recv_c6    AC.000054160454536132656820000016
# 851997    client_log_recv_c6    AC.099950160454537174902420000026
# 866808    client_log_recv_c3    AC.099952160454538550515910000003
# ...                      ...                                  ...
# 8387323   client_log_recv_c2    AN.000170160455239535013510033272
# 8387421   client_log_recv_c5    BP.099566160455239562754220000535
# 8388559   client_log_recv_c2    AN.000168160455239794276410033282
# 8388747  client_log_recv_c18   AN.0001651604552398454948600000918
# 8388947  client_log_recv_c21   AP.0998481604552399101312700016321
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 470570                  3              1604545015722009  gateway_log_up
# ...

# %%
cloudex_df[~ cloudex_df['Order-Serial-Num'].isin(strange_orders)]
# Out:
#             Client-Qual-Recv                             Order-ID  \
# 0        client_log_recv_c36  AA.00023016045445818229201200000036
# 1        client_log_recv_c34  AK.00011616045445818231741200000034
# 2        client_log_recv_c36  AE.00017816045445818250731200000136
# 3        client_log_recv_c34  AG.00032616045445818251771200000134
# 4        client_log_recv_c36  AY.00037716045445818265001200000236
# ...                      ...                                  ...
# 8389284  client_log_recv_c34  CW.00000016045523999552011211057534
# 8389285  client_log_recv_c34  CW.00000016045523999564001211057634
# 8389286  client_log_recv_c34  CW.00000016045523999574881211057734
# 8389287  client_log_recv_c34  CW.00000016045523999586891211057834
# 8389288  client_log_recv_c34  CW.00000016045523999600471211057934
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 0                 8145454              1604544581825426  gateway_log_up
# ...

# %%
8370548+18741
# Out:
# 8389289

# %%
len(cloudex_df)
# Out:
# 8389289

# %%
normal_orders=cloudex_df[~ cloudex_df['Order-Serial-Num'].isin(strange_orders)]

# %%
normal_orders.query('`Gateway-Num` == "g4"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df.query('`Gateway-Num` == "g4"')["Confirmation-Latency-ms"].plot()

# %%
cloudex_df['Confirmation-Latency-ms > 150000']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Confirmation-Latency-ms > 150000'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-164-cf6ec63acd9a> in <module>
# ...

# %%
cloudex_df[cloudex_df['Confirmation-Latency-ms'] > 150000]
# Out:
#             Client-Qual-Recv                            Order-ID  \
# 5733546  client_log_recv_c11  DA.0003831604549818382269425759511
# 5733986  client_log_recv_c11  BC.0003991604549818719809425759611
# 5734427  client_log_recv_c11  BD.0996331604549819078753425759711
# 5735423  client_log_recv_c11  CY.0995021604549819940540425759811
# 5735958  client_log_recv_c11  DA.0003831604549820406521425759911
# ...                      ...                                 ...
# 6634283  client_log_recv_c11  CY.0994811604550794166296427632111
# 6635237  client_log_recv_c11  CO.0003891604550795040090427632211
# 6635527  client_log_recv_c11  BC.0003931604550795315796427632311
# 6635543  client_log_recv_c11  DA.0996131604550795325883427632411
# 6635866  client_log_recv_c11  BD.0003601604550795603162427632511
#
#          Order-Serial-Num  Confirmation-Submission-Time         GW-Qual  \
# 5733546                28              1604550030218645  gateway_log_up
# ...
